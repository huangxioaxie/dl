# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs 
from numpy.random import rand
from sklearn.cluster import Birch

# X为样本特征，Y为样本簇类别， 共1000个样本，每个样本2个特征，共4个簇，簇中心在[-1,-1], [0,0],[1,1], [2,2]
# X, y = make_blobs(n_samples=1000, n_features=2, centers=[[-1,-1], [0,0], [1,1], [2,2]], cluster_std=[0.4, 0.3, 0.4, 0.3], 
#                   random_state =9)

X, y = make_blobs(n_samples=1000, n_features=20)
 
plt.scatter(X[:, 0], X[:, 1], marker='o')
plt.show()

# %%
X,type(X), X.shape
# Out:
# (array([[ -4.97806204,  -4.31642889,   0.183893  , ...,  -7.54125081,
#           -6.48219651,  -7.81211687],
#         [ -2.29754243,   1.80572587,   6.01746887, ..., -10.91238465,
#            5.23447779,  -7.86454641],
#         [ -3.42331396,   4.20285856,   3.97927298, ..., -10.9033017 ,
#            5.88014739,  -9.41641168],
#         ...,
#         [ -8.26100183,  -0.94887556,  -3.52218841, ...,   0.41596125,
#            0.57391478,  -1.00288591],
#         [ -2.99134132,   3.39828673,   5.4846338 , ...,  -8.21586459,
#            6.21289913,  -8.90259254],
#         [ -9.75784407,  -2.20323049,  -4.06781235, ...,  -0.43566776,
#           -1.19162945,   0.65876346]]),
#  numpy.ndarray,
#  (1000, 20))

# %%
y_pred = Birch(n_clusters = 999).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

print ("Calinski-Harabasz Score", metrics.calinski_harabasz_score(X, y_pred))
# Out:
# Calinski-Harabasz Score 103.26777885446812

# %%
y_pred = Birch(n_clusters = 4, threshold = 0.3).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
print ("Calinski-Harabasz Score", metrics.calinski_harabasz_score(X, y_pred))
# Out:
# Calinski-Harabasz Score 4558.8655780579875

# %%
y_pred = Birch(n_clusters = 4, threshold = 0.1).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
print ("Calinski-Harabasz Score", metrics.calinski_harabasz_score(X, y_pred))
# Out:
# Calinski-Harabasz Score 4558.8655780579875

# %%
y_pred = Birch(n_clusters = 4, threshold = 0.5).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
print ("Calinski-Harabasz Score", metrics.calinski_harabasz_score(X, y_pred))
# Out:
# Calinski-Harabasz Score 4558.8655780579875

# %%
y_pred = Birch( threshold = 0.3, branching_factor=50).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
print ("Calinski-Harabasz Score", metrics.calinski_harabasz_score(X, y_pred))
# Out:
# Calinski-Harabasz Score 6770.042816147823

# %%
import jieba

# 全模式
text = "自然语言处理（NLP）是一种专业用来分析人类语言的人工智能技术"
seg_list = jieba.cut(text, cut_all=True)
print(u"[全模式]: ", " ".join(seg_list))

# 精确模式
seg_list = jieba.cut(text, cut_all=False)
print(u"[精确模式]: ", "  ".join(seg_list))

# 默认是精确模式
seg_list = jieba.cut(text)
print(u"[默认模式]: ", " ".join(seg_list))

# 搜索引擎模式
seg_list = jieba.cut_for_search(text)
print(u"[搜索引擎模式]: ", " ".join(seg_list))
# Out:
# [全模式]:  自然 自然语言 语言 处理 （ NLP ） 是 一种 专业 用来 分析 人类 语言 的 人工 人工智能 智能 技术
# [精确模式]:  自然语言  处理  （  NLP  ）  是  一种  专业  用来  分析  人类  语言  的  人工智能  技术
# [默认模式]:  自然语言 处理 （ NLP ） 是 一种 专业 用来 分析 人类 语言 的 人工智能 技术
# [搜索引擎模式]:  自然 语言 自然语言 处理 （ NLP ） 是 一种 专业 用来 分析 人类 语言 的 人工 智能 人工智能 技术

# %%
import os
file = "c:/data/news/test01.csv"
os.path.exists(file)
# Out:
# True
