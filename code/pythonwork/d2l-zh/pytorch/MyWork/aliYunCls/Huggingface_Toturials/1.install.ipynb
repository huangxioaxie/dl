# %%
#环境
#python=3.6
#pytorch=1.10

# %%
#安装transformers
#pip安装
#pip install transformers

#conda安装
#conda install -c huggingface transformers

# %%
#安装datasets
#pip安装
# !pip install datasets
# !pip install ipywidgets
#conda安装
#conda install -c huggingface -c conda-forge datasets
# Out:
# Collecting datasets
#   Downloading datasets-1.18.3-py3-none-any.whl (311 kB)
# Collecting dill
#   Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from datasets) (2.25.1)
# Collecting pyarrow!=4.0.0,>=3.0.0
#   Using cached pyarrow-7.0.0-cp38-cp38-win_amd64.whl (16.1 MB)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from datasets) (4.63.0)
# Collecting xxhash
#   Using cached xxhash-3.0.0-cp38-cp38-win_amd64.whl (29 kB)
# Requirement already satisfied: pandas in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from datasets) (1.2.2)
# Collecting fsspec[http]>=2021.05.0
#   Using cached fsspec-2022.2.0-py3-none-any.whl (134 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from datasets) (1.18.5)
# Collecting multiprocess
#   Using cached multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: packaging in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from datasets) (21.3)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp38-cp38-win_amd64.whl (555 kB)
# Requirement already satisfied: pyyaml in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from requests>=2.19.0->datasets) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: colorama in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp38-cp38-win_amd64.whl (33 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-win_amd64.whl (122 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp38-cp38-win_amd64.whl (28 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Installing collected packages: multidict, frozenlist, yarl, charset-normalizer, async-timeout, aiosignal, fsspec, dill, aiohttp, xxhash, pyarrow, multiprocess, datasets
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 charset-normalizer-2.0.12 datasets-1.18.3 dill-0.3.4 frozenlist-1.3.0 fsspec-2022.2.0 multidict-6.0.2 multiprocess-0.70.12.2 pyarrow-7.0.0 xxhash-3.0.0 yarl-1.7.2
# Requirement already satisfied: ipywidgets in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (7.6.5)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (6.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipywidgets) (8.0.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: decorator in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.28)
# Requirement already satisfied: pickleshare in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: black in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (22.1.0)
# Requirement already satisfied: pygments in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: backcall in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (303)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.7.0)
# Requirement already satisfied: wcwidth in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (4.1.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (0.9.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (8.0.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from black->ipython>=4.0.0->ipywidgets) (2.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.11)
# Requirement already satisfied: testpath in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: packaging in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: webencodings in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.7)
# Requirement already satisfied: executing in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.2)
# Requirement already satisfied: pure-eval in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\hys\anaconda3\envs\d2l\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
